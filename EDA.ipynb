# %% [markdown]
# <a href="https://colab.research.google.com/github/ajlr2003/EDA-on-Income-Analysis/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the census and GDP data
census_df = pd.read_csv('india-districts-census-2011.csv')
gdp_df = pd.read_csv('gdp_AndhraPradesh1.csv')

census_df.head()
census_df.info()
census_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Columns: 118 entries, District code to Total_Power_Parity
# dtypes: int64(116), object(2)
# memory usage: 590.1+ KB
# District code                    0
# State Name                       0
# District name                    0
# Population                       0
# Male                             0
#                                 ..
# Power_Parity_Rs_330000_425000    0
# Power_Parity_Rs_425000_545000    0
# Power_Parity_Rs_330000_545000    0
# Power_Parity_Above_Rs_545000     0
# Total_Power_Parity               0
# Length: 118, dtype: int64

# %%
for col in census_df.columns:
    print(f"{col}: {census_df[col].nunique()} unique values")

census_df.describe()
# Out:
# District code: 640 unique values
# State Name: 35 unique values
# District name: 634 unique values
# Population: 640 unique values
# Male: 640 unique values
# Female: 640 unique values
# Literate: 640 unique values
# Male_Literate: 640 unique values
# Female_Literate: 640 unique values
# SC: 610 unique values
# Male_SC: 608 unique values
# Female_SC: 604 unique values
# ST: 584 unique values
# Male_ST: 583 unique values
# Female_ST: 582 unique values
# Workers: 640 unique values
# Male_Workers: 640 unique values
# Female_Workers: 640 unique values
# Main_Workers: 640 unique values
# Marginal_Workers: 640 unique values
# Non_Workers: 640 unique values
# Cultivator_Workers: 639 unique values
# Agricultural_Workers: 640 unique values
# Household_Workers: 632 unique values
# Other_Workers: 640 unique values
# Hindus: 640 unique values
# Muslims: 639 unique values
# Christians: 622 unique values
# Sikhs: 565 unique values
# Buddhists: 511 unique values
# Jains: 546 unique values
# ...

# %%
print(census_df.columns.tolist())
# Out:
# ['District code', 'State Name', 'District name', 'Population', 'Male', 'Female', 'Literate', 'Male_Literate', 'Female_Literate', 'SC', 'Male_SC', 'Female_SC', 'ST', 'Male_ST', 'Female_ST', 'Workers', 'Male_Workers', 'Female_Workers', 'Main_Workers', 'Marginal_Workers', 'Non_Workers', 'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers', 'Other_Workers', 'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains', 'Others_Religions', 'Religion_Not_Stated', 'LPG_or_PNG_Households', 'Housholds_with_Electric_Lighting', 'Households_with_Internet', 'Households_with_Computer', 'Rural_Households', 'Urban_Households', 'Households', 'Below_Primary_Education', 'Primary_Education', 'Middle_Education', 'Secondary_Education', 'Higher_Education', 'Graduate_Education', 'Other_Education', 'Literate_Education', 'Illiterate_Education', 'Total_Education', 'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50', 'Age not stated', 'Households_with_Bicycle', 'Households_with_Car_Jeep_Van', 'H
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Only include columns that exist
income_cols = ['Power_Parity_Above_Rs_545000']  # Adjusted to your dataset

for col in income_cols:
    plt.figure(figsize=(12, 6))
    sns.histplot(census_df[col], bins=30, kde=True, color='skyblue')
    plt.title(f'Distribution of {col}')
    plt.xlabel('Number of Households')
    plt.ylabel('District Count')
    plt.show()

# %%
# Correct column name: 'State Name'
state_income = census_df.groupby('State Name')[income_cols].sum().sort_values(by='Power_Parity_Above_Rs_545000', ascending=False)

# Visualization
state_income['Power_Parity_Above_Rs_545000'].plot(kind='bar', figsize=(12, 6), color='lightgreen')
plt.title('High Income Population (Rs. 5.45L+) by State')
plt.xlabel('State')
plt.ylabel('Number of Households')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
for col in census_df.columns:
    print(f"{col}: {census_df[col].nunique()} unique values")
# Out:
# District code: 640 unique values
# State Name: 35 unique values
# District name: 634 unique values
# Population: 640 unique values
# Male: 640 unique values
# Female: 640 unique values
# Literate: 640 unique values
# Male_Literate: 640 unique values
# Female_Literate: 640 unique values
# SC: 610 unique values
# Male_SC: 608 unique values
# Female_SC: 604 unique values
# ST: 584 unique values
# Male_ST: 583 unique values
# Female_ST: 582 unique values
# Workers: 640 unique values
# Male_Workers: 640 unique values
# Female_Workers: 640 unique values
# Main_Workers: 640 unique values
# Marginal_Workers: 640 unique values
# Non_Workers: 640 unique values
# Cultivator_Workers: 639 unique values
# Agricultural_Workers: 640 unique values
# Household_Workers: 632 unique values
# Other_Workers: 640 unique values
# Hindus: 640 unique values
# Muslims: 639 unique values
# Christians: 622 unique values
# Sikhs: 565 unique values
# Buddhists: 511 unique values
# Jains: 546 unique values
# ...
